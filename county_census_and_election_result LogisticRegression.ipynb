# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
census_raw = pd.read_csv("../Data files/county_census_and_election_result.csv")

# %%
census_raw.head()
# Out:
#    year  county_fips   inctot  mortamt1  avrg_age  ftotinc  foodstmp_1_freq  \
# 0  2000            1  24566.4     634.6      46.0  46912.7             93.6
# 1  2000            2  33842.9    1080.1      42.4  65021.9             95.3
# 2  2000            4  28331.7     814.7      45.3  52826.7             95.8
# 3  2000            5  22782.6     557.5      46.2  43941.3             92.5
# 4  2000            6  32245.0    1216.3      43.8  61455.3             95.7
#
#    foodstmp_2_freq  sex_2_freq  sex_1_freq  ...  empstat_3.0_freq  \
# 0              6.4        54.0        46.0  ...              38.4
# 1              4.7        50.3        49.7  ...              25.2
# 2              4.2        52.1        47.9  ...              38.3
# 3              7.5        53.0        47.0  ...              37.8
# 4              4.3        52.0        48.0  ...              35.1
#
#    empstat_2.0_freq  state_po  county_name  democrat  green  liberitarian  \
# ...

# %%
census_raw.isnull().sum()
# Out:
# year                       0
# county_fips                0
# inctot                     0
# mortamt1                   0
# avrg_age                   0
# ftotinc                    0
# foodstmp_1_freq            0
# foodstmp_2_freq            0
# sex_2_freq                 0
# sex_1_freq                 0
# marst_5_freq               0
# marst_6_freq               0
# marst_1_freq               0
# marst_4_freq               0
# marst_3_freq               0
# marst_2_freq               0
# race_1_freq                0
# race_2_freq                0
# race_7_freq                0
# race_8_freq                0
# race_5_freq                0
# race_6_freq                0
# race_3_freq                0
# race_4_freq                0
# race_9_freq                0
# ctz_stat_1_freq            0
# ctz_stat_3_freq            0
# ctz_stat_2_freq            0
# lang_1_freq                0
# lang_2_freq                0
# educ_attain_2.0_freq       0
# educ_attain_1.0_freq       0
# ...

# %%
census_data  = census_raw.dropna()

# %%
census_raw.shape
# Out:
# (7526, 45)

# %%
census_data.shape
# Out:
# (1670, 45)

# %%
census_raw.isnull().sum().sum()/(7526*45)
# Out:
# 0.13832934715209497

# %%
(1670*45)/(7526*45)
# Out:
# 0.22189742226946585

# %%
census_data.corr()
# Out:
#                           year  county_fips    inctot  mortamt1  avrg_age  \
# year                  1.000000     0.008370  0.079725 -0.054628  0.269495
# county_fips           0.008370     1.000000 -0.006036 -0.114687 -0.088672
# inctot                0.079725    -0.006036  1.000000  0.808655  0.086146
# mortamt1             -0.054628    -0.114687  0.808655  1.000000 -0.062928
# avrg_age              0.269495    -0.088672  0.086146 -0.062928  1.000000
# ftotinc               0.173110    -0.011716  0.936565  0.796413  0.099536
# foodstmp_1_freq      -0.081564    -0.014829  0.597355  0.398092  0.036352
# foodstmp_2_freq       0.081564     0.014829 -0.597355 -0.398092 -0.036352
# sex_2_freq           -0.218296     0.000025  0.075191  0.063709  0.011788
# sex_1_freq            0.218296    -0.000025 -0.075191 -0.063709 -0.011788
# marst_5_freq         -0.129820    -0.063210 -0.371328 -0.367085  0.573109
# marst_6_freq          0.273057    -0.039250 -0.054946  0.134084 -0.485388
# ...

# %%
census_data = census_data.drop(columns=['year','county_fips', 'state_po', 'county_name', 'democrat',
                                             'green', 'liberitarian', 'other', 'republican'])

# %%
census_data.shape
# Out:
# (1670, 36)

# %%
census_data['winner'].value_counts()
# Out:
# 0.0    854
# 1.0    816
# Name: winner, dtype: int64

# %%
X = census_data.iloc[:,:-1]

# %%
y = census_data.iloc[:,-1]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
# training the model
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 79.04%

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_test, y_pred)
plt.figure()
sns.heatmap(cf, annot=True)
plt.xlabel('Prediction')
plt.ylabel('Target')
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
census_data.head(100)
# Out:
#        inctot  mortamt1  avrg_age  ftotinc  foodstmp_1_freq  foodstmp_2_freq  \
# 1529  27222.4     902.2      48.6  53308.6             94.2              5.8
# 1530  20951.6     551.7      47.1  39712.5             89.1             10.9
# 1531  24017.6     658.6      48.2  47650.0             94.2              5.8
# 1532  28109.5     812.4      47.2  54993.2             93.5              6.5
# 1533  24870.4     725.1      40.6  45575.0             92.4              7.6
# ...       ...       ...       ...      ...              ...              ...
# 1631  35426.2    1050.0      43.4  70532.2             98.2              1.8
# 1632  22000.2     737.2      42.5  43063.8             86.9             13.1
# 1633  37924.5    1065.8      44.5  72126.2             96.8              3.2
# 1634  32732.2    1018.1      44.2  59279.6             92.1              7.9
# 1635  41166.5    1300.9      44.0  75460.3             92.7              7.3
#
# ...

# %%
data = [[
41166.5,
1300.9,
44,
75460.3,
92.7,
7.3,
52.7,
47.3,
5.7,
34.7,
44.7,
11.1,
2,
1.8,
52.4,
39.8,
1.4,
0.9,
0.1,
4,
0.2,
1.2,
0.1,
86.7,
8.2,
5.1,
86.2,
13.8,
53.4,
29.3,
15.5,
1.8,
65.4,
30.2,
4.4]]

# %%
result = clf.predict(data)

# %%
print(result)
# Out:
# [1]
